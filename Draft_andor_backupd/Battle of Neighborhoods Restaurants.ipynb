# %% [markdown]
# ## Imports

# %%
import io
import re
import json
#import config still testing
import folium
import requests
import numpy as np
import pandas as pd
import wikipedia as wp

from bs4 import BeautifulSoup
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize

# zip code stuff
import uszipcode
from uszipcode import Zipcode
from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)

# graphing 
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
# %matplotlib inline

# %% [markdown]
# ### Declare City List

# %%
city_list = [
    'Baltimore',
    'Baltimore County',
    'Richmond',
    'Henrico County',
    'Phoenix',
    'Maricopa County',
    'Houston',
    'Harris County'
]

# %% [markdown]
# ### Declare City List with State

# %%
city_state = [
    ['Baltimore', 'Maryland'],
    ['Baltimore County', 'Maryland'],
    ['Richmond', 'Virginia'],
    ['Henrico County', 'Virginia'],
    ['Phoenix', 'Arizona'],
    ['Maricopa County', 'Arizona'],
    ['Houston', 'Texas'],
    ['Harris County', 'Texas']
]

# %% [markdown]
# ### Declare Codinates DataFrame

# %%
header = ['City', 'Latitude', 'Longitude']
comb = [
    ['Baltimore', 39.283333, -76.616667],
    ['Baltimore County', 39.4, -76.6],
    ['Richmond', 37.533333, -77.466667],
    ['Henrico County', 37.55, -77.4],
    ['Phoenix', 33.45, -112.066667],
    ['Maricopa County', 33.513889, -112.475833],
    ['Houston', 29.762778, -95.383056],
    ['Harris County', 29.86, -95.39]
]

tempC = []
tempLat = []
tempLong = []
for c in comb:
    tempC.append(c[0])
    tempLat.append(c[1])
    tempLong.append(c[2])

#NDF = new dataframe
NDF = {
    str(header[0]): tempC,
    str(header[1]): tempLat,
    str(header[2]): tempLong
}

# CDF = cords dataframe
CDF = pd.DataFrame(NDF, columns = ['City', 'Latitude', 'Longitude'])

cities = CDF[header[0]]
lat = CDF[header[1]]
long = CDF[header[2]]

# %% [markdown]
# ### Foursquare Creds

# %%
CLIENT_ID = 'TL2E0LDIYOXQH22H13SIGIGDAZRVEF4HCZSM0KQ2XJKXDHKK' # foursquare ID
CLIENT_SECRET = 'U0YKWNDNGW22DNPJMM4CXUKRDMJH2CII0PPRFISGL3HZLUHP' # foursquare Secret
VERSION = '20200712'
LIMIT = 100

# %% [markdown]
# ### Initialize Maps V1

# %%
# lets start with the 4 main cities
#print(cities)
#print(lat)
#print(long)

baltimore_city_map = folium.Map(location=[lat[0], long[0]], zoom_start=10)
baltimore_county_map = folium.Map(location=[lat[1], long[1]], zoom_start=10)
richmond_city_map = folium.Map(location=[lat[2], long[2]], zoom_start=10)
henrico_county_map = folium.Map(location=[lat[3], long[3]], zoom_start=10)
phoenix_city_map = folium.Map(location=[lat[4], long[4]], zoom_start=10)
maricopa_county_map = folium.Map(location=[lat[5], long[5]], zoom_start=10)
houston_city_map = folium.Map(location=[lat[6], long[6]], zoom_start=10)
harris_county_map = folium.Map(location=[lat[7], long[7]], zoom_start=10)

# lc = location class
# add them all to a list
maps = [
    baltimore_city_map, # lc1
    baltimore_county_map, # lc1
    richmond_city_map, # lc2
    henrico_county_map, # lc2
    phoenix_city_map, # lc3
    maricopa_county_map, # lc3
    houston_city_map, # lc4
    harris_county_map # lc4
]

# %% [markdown]
# ### Function to get Zipcodes based on range OLD

# %%
"""
OLD
# gzcr = getZipCodeRange
# might not need this
def gzcr(startN, endN):
    l1 = [] # list 1
    addrRange = range(startN, endN + 1)
    for val in addrRange:
        l1.append(val)
        
    return l1
"""

# %% [markdown]
# ### Make master Zipcode list OLD

# %%
"""
OLD
zipList = [
    [21201, 21298], # lc1
    []
]
"""
# Out:
# '\nzipList = [\n    [21201, 21298], # lc1\n    []\n]\n'

# %% [markdown]
# ### Get all Zips

# %%
all_zip = []

# search for all the zips and add them to a list
for cs in city_state:
    temp1 = search.by_city_and_state(cs[0], cs[1])
    for t in temp1:
        tempL = [cs[0]]
        tempL.append(t.zipcode)
        if len(t.common_city_list) != 0:
            tempL.append(t.common_city_list[-1])
        else:
            tempL.append(cs[0]+'?')
        tempL.append(t.lat)
        tempL.append(t.lng)
        all_zip.append(tempL)

# format for all_zip [[city, zip, common city, lat, long]]

# remove the none from the cord and put the previous val in
prevE = []
for az in all_zip:
    if az[3] == None:
        az[3] = prevE[-1][0]
    if az[4] == None:
        az[4] = prevE[-1][-1]
    
    temp = [az[3], az[4]]
    prevE.append(temp)

# %% [markdown]
# ### Turn all_zips into a DataFrame

# %%
header = ['City', 'Zip', 'Common City', 'Latitude', 'Longitude']
TC = []
TZ = []
TCC = []
TLo = []
TLa = []

for az2 in all_zip:
    TC.append(az2[0])
    TZ.append(az2[1])
    TCC.append(az2[2])
    TLo.append(az2[3])
    TLa.append(az2[4])

tNDF = {
    header[0]:TC,
    header[1]:TZ,
    header[2]:TCC,
    header[3]:TLo,
    header[4]:TLa
}

all_zipDF = pd.DataFrame(tNDF, columns = ['City', 'Zip', 'Common City', 'Latitude', 'Longitude'])

all_zipDF.head()
# Out:
#         City    Zip       Common City  Latitude  Longitude
# 0  Baltimore  21201        Baltimore?     39.29     -76.62
# 1  Baltimore  21202         Baltimore     39.30     -76.61
# 2  Baltimore  21205        Baltimore?     39.30     -76.57
# 3  Baltimore  21206         Baltimore     39.34     -76.54
# 4  Baltimore  21209  Mount Washington     39.37     -76.68

# %% [markdown]
# ### Make Labels

# %%
labels = []
for c in cities:
    temp = folium.Popup(c)
    labels.append(temp)

# %% [markdown]
# ### Make Circle Markers

# %%
# cm = Circle Markers
cm = []

x = 0

while x != 8:
    folium.CircleMarker(
        [lat[x], long[x]],
        radius=5,
        popup=labels[x],
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(maps[x])
    x += 1

# %% [markdown]
# ### Initialize Maps V2

# %%
# all_zipDF
# centers with baltimore
addr = 'Baltimore'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(addr)
latitude = location.latitude
longitude = location.longitude
#print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

main_map2 = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, city, CC in zip(all_zipDF['Latitude'], all_zipDF['Longitude'], all_zipDF['City'], all_zipDF['Common City']):
    label = '{}, {}'.format(city, CC)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(main_map2)

    
main_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Get Category Function

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ### Get Venues

# %%
# FourSqure url
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, 500, LIMIT)

results = requests.get(url).json()
results

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
#dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
fc = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, fc]

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                    name   categories  \
# 0                   Baltimore City Hall    City Hall
# 1                             The Block        Plaza
# 2  Clarence "Du" Burns Council Chambers    City Hall
# 3                   The Benton Building     Building
# 4                 Shelly's Blossom Shop  Flower Shop
#
#                      address  cc       city        country  \
# 0            100 Holliday St  US  Baltimore  United States
# 1  400 blk of E Baltimore St  US  Baltimore  United States
# 2            100 Holliday St  US  Baltimore  United States
# 3           417 E Fayette St  US  Baltimore  United States
# 4         218 E Lexington St  US  Baltimore  United States
#
#                          crossStreet  distance  \
# 0            btw Fayette & Lexington        34
# 1                btwn Commerce & Gay       180
# 2  btw E Fayette St & E Lexington St        19
# 3                        at N Gay St       133
# 4                           Guilford        72
#
#                                     formattedAddress  \
# 0  [100 Holliday St (btw Fayette & Lexington), Ba...
# 1  [400 blk of E Baltimore St (btwn Commerce & Ga...
# 2  [100 Holliday St (btw E Fayette St & E Lexingt...
# 3  [417 E Fayette St (at N Gay St), Baltimore, MD...
# 4  [218 E Lexington St (Guilford), Baltimore, MD ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 39.29084152348969...  39.290842 -76.610366
# 1  [{'label': 'display', 'lat': 39.2898184715289,...  39.289818 -76.609180
# 2  [{'label': 'display', 'lat': 39.29088592529297...  39.290886 -76.610535
# 3  [{'label': 'display', 'lat': 39.29047054068511...  39.290471 -76.609299
# 4  [{'label': 'display', 'lat': 39.2913953, 'lng'...  39.291395 -76.611270
#
#   postalCode state                        id
# 0      21202    MD  4ae1da9df964a520fb8721e3
# 1      21202    MD  4b7b5ab1f964a5209d5f2fe3
# 2      21202    MD  4c752a431b30a093907eee09
# 3      21202    MD  4bbccf56f57ba5938945adb9
# 4      21202    MD  506b3021e4b0078b677b37bc

# %% [markdown]
# ### Function to get venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City', 
                  'City Latitude', 
                  'Cirt Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### List all nearby venues

# %%
all_venues = getNearbyVenues(names=all_zipDF['City'],
                                   latitudes=all_zipDF['Latitude'],
                                   longitudes=all_zipDF['Longitude']
                                  )
# Out:
# Baltimore
# Baltimore
# Baltimore
# Baltimore
# Baltimore
# Baltimore County
# Baltimore County
# Baltimore County
# Baltimore County
# Baltimore County
# Richmond
# Richmond
# Richmond
# Richmond
# Richmond
# Henrico County
# Henrico County
# Henrico County
# Henrico County
# Henrico County
# Phoenix
# Phoenix
# Phoenix
# Phoenix
# Phoenix
# Maricopa County
# Maricopa County
# Maricopa County
# Maricopa County
# Houston
# Houston
# Houston
# Houston
# Houston
# Harris County
# Harris County
# Harris County
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Baltimore                  39.29                  -76.62
# 1    Baltimore                  39.29                  -76.62
# 2    Baltimore                  39.29                  -76.62
# 3    Baltimore                  39.29                  -76.62
# 4    Baltimore                  39.29                  -76.62
#
#                                                Venue  Venue Latitude  \
# 0                                            Nando's       39.289289
# 1  The Hippodrome Theatre at the France-Merrick P...       39.289732
# 2                               The Everyman Theatre       39.290359
# 3                           Bromo Seltzer Arts Tower       39.287543
# 4                                 Cafe on the Square       39.288889
#
#    Venue Longitude         Venue Category
# 0       -76.621977  Portuguese Restaurant
# 1       -76.621378                Theater
# 2       -76.620444                Theater
# 3       -76.620854    Monument / Landmark
# 4       -76.622226         Sandwich Place

# %% [markdown]
# ### Venues:

# %%
print('{} Venues were returned by Foursquare.'.format(all_venues.shape[0]))
# Out:
# 585 Venues were returned by Foursquare.

# %% [markdown]
# ### Number of venues per Neighborhood

# %%
all_venues.groupby('Neighborhood').count()
# Out:
#                   Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Baltimore                           112                     112    112
# Baltimore County                    112                     112    112
# Harris County                        15                      15     15
# Henrico County                       54                      54     54
# Houston                             104                     104    104
# Phoenix                             140                     140    140
# Richmond                             48                      48     48
#
#                   Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Baltimore                    112              112             112
# Baltimore County             112              112             112
# Harris County                 15               15              15
# Henrico County                54               54              54
# Houston                      104              104             104
# Phoenix                      140              140             140
# Richmond                      48               48              48

# %%
# unique categories
print('There are {} uniques categories.\n\n'.format(len(all_venues['Venue Category'].unique())))

# one hot encoding
all_onehot = pd.get_dummies(all_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
all_onehot['Neighborhood'] = all_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [all_onehot.columns[-1]] + list(all_onehot.columns[:-1])
manhattan_onehot = all_onehot[fixed_columns]

all_onehot.head()

all_grouped = all_onehot.groupby('Neighborhood').mean().reset_index()
all_grouped.head()
# Out:
# There are 156 uniques categories.
#        Neighborhood  Accessories Store  Afghan Restaurant  \
# 0         Baltimore                0.0           0.008929
# 1  Baltimore County                0.0           0.008929
# 2     Harris County                0.0           0.000000
# 3    Henrico County                0.0           0.000000
# 4           Houston                0.0           0.000000
#
#    American Restaurant  Art Gallery  Arts & Entertainment  Asian Restaurant  \
# 0             0.026786          0.0              0.000000          0.000000
# 1             0.026786          0.0              0.000000          0.000000
# 2             0.000000          0.0              0.000000          0.000000
# 3             0.018519          0.0              0.018519          0.000000
# 4             0.009615          0.0              0.000000          0.009615
#
#    Athletics & Sports  BBQ Joint  Bagel Shop  ...  Thai Restaurant   Theater  \
# 0            0.000000   0.008929    0.000000  ...         0.008929  0.044643
# 1            0.000000   0.008929    0.000000  ...         0.008929  0.044643
# 2            0.000000   0.000000    0.000000  ...         0.000000  0.000000
# 3            0.000000   0.000000    0.018519  ...         0.018519  0.000000
# 4            0.009615   0.019231    0.000000  ...         0.019231  0.009615
#
#    Theme Restaurant  Thrift / Vintage Store     Trail  Train Station  \
# 0               0.0                0.000000  0.000000            0.0
# 1               0.0                0.000000  0.000000            0.0
# 2               0.0                0.000000  0.000000            0.0
# 3               0.0                0.018519  0.000000            0.0
# 4               0.0                0.000000  0.009615            0.0
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Wine Bar  Wine Shop
# 0                            0.0               0.017857  0.000000   0.000000
# 1                            0.0               0.017857  0.000000   0.000000
# 2                            0.0               0.000000  0.066667   0.000000
# 3                            0.0               0.000000  0.000000   0.018519
# 4                            0.0               0.000000  0.009615   0.000000
#
# [5 rows x 156 columns]

# %% [markdown]
# ### Return common venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ### Top Venues

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create the columns according to number of top venues
columns = ['Neighborhood']

for ind in np.arange(num_top_venues):
    try: 
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)

neighborhoods_venues_sorted['Neighborhood'] = all_grouped['Neighborhood']

for ind in np.arange(all_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(all_grouped.iloc[ind, :], num_top_venues)


    
neighborhoods_venues_sorted.head()
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0         Baltimore                  Café        Sandwich Place
# 1  Baltimore County                  Café        Sandwich Place
# 2     Harris County           Coffee Shop                  Pool
# 3    Henrico County           Coffee Shop         Jewelry Store
# 4           Houston           Coffee Shop                   Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 0           Pizza Place           Coffee Shop               Theater
# 1           Pizza Place           Coffee Shop               Theater
# 2        Breakfast Spot     Health Food Store              Wine Bar
# 3        Cosmetics Shop     Mobile Phone Shop    Mexican Restaurant
# 4                   Gym  Gym / Fitness Center   Rental Car Location

# %%
all_zipDF
# Out:
#                 City    Zip            Common City  Latitude  Longitude
# 0          Baltimore  21201             Baltimore?     39.29     -76.62
# 1          Baltimore  21202              Baltimore     39.30     -76.61
# 2          Baltimore  21205             Baltimore?     39.30     -76.57
# 3          Baltimore  21206              Baltimore     39.34     -76.54
# 4          Baltimore  21209       Mount Washington     39.37     -76.68
# 5   Baltimore County  21201      Baltimore County?     39.29     -76.62
# 6   Baltimore County  21202              Baltimore     39.30     -76.61
# 7   Baltimore County  21205      Baltimore County?     39.30     -76.57
# 8   Baltimore County  21206              Baltimore     39.34     -76.54
# 9   Baltimore County  21209       Mount Washington     39.37     -76.68
# 10          Richmond  23219               Richmond     37.54     -77.46
# 11          Richmond  23220               Richmond     37.55     -77.46
# 12          Richmond  23221               Richmond     37.55     -77.49
# 13          Richmond  23222               Richmond     37.58     -77.42
# 14          Richmond  23223               Richmond     37.56     -77.37
# 15    Henrico County  23075       Highland Springs     37.55     -77.32
# 16    Henrico County  23228               Richmond     37.63     -77.50
# 17    Henrico County  23229               Richmond     37.59     -77.57
# 18    Henrico County  23231               Richmond     37.40     -77.30
# 19    Henrico County  23233                  Ridge     37.65     -77.62
# 20           Phoenix  85003                Phoenix     33.45    -112.08
# 21           Phoenix  85004                Phoenix     33.45    -112.07
# 22           Phoenix  85006                Phoenix     33.47    -112.05
# 23           Phoenix  85007                Phoenix     33.45    -112.09
# 24           Phoenix  85008                Phoenix     33.46    -111.99
# 25   Maricopa County  85138               Maricopa     33.00    -111.90
# 26   Maricopa County  85139                 Mobile     33.10    -112.20
# 27   Maricopa County  85238               Maricopa     33.10    -112.20
# 28   Maricopa County  85239                 Mobile     33.10    -112.20
# 29           Houston  77002            Clutch City     29.75     -95.37
# 30           Houston  77003                Houston     29.75     -95.35
# 31           Houston  77004                Houston     29.72     -95.38
# 32           Houston  77005  West University Place     29.72     -95.42
# 33           Houston  77006                Houston     29.74     -95.39
# 34     Harris County  75033                 Frisco     29.74     -95.39
# 35     Harris County  75034                 Frisco     33.12     -96.88
# 36     Harris County  75035                 Frisco     33.16     -96.77

# %% [markdown]
# ### Get Population & Population Density

# %%
Pheader = ['City', 'Zip', 'Population', 'Population Density']
Pcity = all_zipDF['City']
Pzip = all_zipDF['Zip']
popL = []
popDL = []

for z in Pzip:
    temp = search.by_zipcode(z)
    pop = temp.population
    popD = temp.population_density
    
    #print("{} || pop: {} || pop dense {}\n".format(z, temp.population, temp.population_density))

    if pop != None or popD != None:
        popL.append(pop)
        popDL.append(popD)
    else:
        popL.append(np.nan)
        popDL.append(np.nan)
        
popNDF = {
    Pheader[0]: Pcity,
    Pheader[1]: Pzip,
    Pheader[2]: popL,
    Pheader[3]: popDL
}

popDF = pd.DataFrame(popNDF, columns = ['City', 'Zip', 'Population', 'Population Density'])
popDF = popDF.dropna()
popDF
# Out:
#                 City    Zip  Population  Population Density
# 0          Baltimore  21201     16972.0             13158.0
# 1          Baltimore  21202     22832.0             14384.0
# 2          Baltimore  21205     16146.0              7883.0
# 3          Baltimore  21206     50846.0              7055.0
# 4          Baltimore  21209     26465.0              3734.0
# 5   Baltimore County  21201     16972.0             13158.0
# 6   Baltimore County  21202     22832.0             14384.0
# 7   Baltimore County  21205     16146.0              7883.0
# 8   Baltimore County  21206     50846.0              7055.0
# 9   Baltimore County  21209     26465.0              3734.0
# 10          Richmond  23219      3781.0              2464.0
# 11          Richmond  23220     35545.0              7400.0
# 12          Richmond  23221     13680.0              4143.0
# 13          Richmond  23222     24563.0              2959.0
# 14          Richmond  23223     47677.0              2830.0
# 15    Henrico County  23075      9819.0              2142.0
# 16    Henrico County  23228     34198.0              3054.0
# 17    Henrico County  23229     32283.0              2262.0
# 18    Henrico County  23231     34685.0               393.0
# 19    Henrico County  23233     28908.0              2342.0
# 20           Phoenix  85003      9369.0              5061.0
# 21           Phoenix  85004      4965.0              2434.0
# 22           Phoenix  85006     25742.0              6595.0
# 23           Phoenix  85007     14040.0              3110.0
# 24           Phoenix  85008     56145.0              5364.0
# 25   Maricopa County  85138     33633.0               454.0
# 26   Maricopa County  85139     17979.0                93.0
# 29           Houston  77002     16793.0              8320.0
# 30           Houston  77003     10508.0              4144.0
# 31           Houston  77004     32692.0              5660.0
# 32           Houston  77005     25528.0              6639.0
# 33           Houston  77006     19664.0              8720.0
# 35     Harris County  75034     72723.0              1454.0
# 36     Harris County  75035     47553.0              2011.0

# %% [markdown]
# ### Get Minium Function

# %%
def getMin(l1): # l1 is a list
    #print(min(l1))
    return min(l1)

# %% [markdown]
# ### Get Maxium Function

# %%
def getMax(l1): # l1 is a list
    #print(max(l1))
    return max(l1)

# %% [markdown]
# ### Plot testing

# %%
p = popDF
TP = p['Population']
TPD = p['Population Density']

TP_min = getMin(TP)
TP_max = getMax(TP)
TPD_min = getMin(TPD)
TPD_max = getMax(TPD)
bg = [TP_min/10, TP_max/100, TPD_min*10, TPD_max/10] # bar graph data
x = ['Pop Min', 'Pop Max/100', 'Pop Den Min*100', 'Pop Den Max']

plt.style.use('ggplot')

x_pos = [i for i, _ in enumerate(bg)]

plt.bar(x_pos, bg, color='green')

plt.xticks(x_pos, x)
plt.xlabel('Population Data')
plt.ylabel('Value')
plt.title('Population Graph')
plt.show()

# %%
len(all_venues)
# Out:
# 585

# %%
mlv = [] # master venue list

x = 0
for y in all_venues['Venue Category']:
    if y not in mlv:
        mlv.append(y)
    x += 1

# %%
mlv
# Out:
# ['Portuguese Restaurant',
#  'Theater',
#  'Monument / Landmark',
#  'Sandwich Place',
#  'Fish Market',
#  'Breakfast Spot',
#  'Afghan Restaurant',
#  'Coffee Shop',
#  'Italian Restaurant',
#  'Peruvian Restaurant',
#  'Food Truck',
#  'Pizza Place',
#  'BBQ Joint',
#  'Café',
#  'Hotel',
#  'Deli / Bodega',
#  'Vietnamese Restaurant',
#  'New American Restaurant',
#  'Church',
#  'Liquor Store',
#  'Hotel Bar',
#  'Ethiopian Restaurant',
#  'Indian Restaurant',
#  'Bakery',
#  'Dog Run',
#  'Boarding House',
#  'Gastropub',
#  'Gym / Fitness Center',
#  'Thai Restaurant',
#  'French Restaurant',
#  'Rental Car Location',
#  'Convenience Store',
#  'Bank',
#  'Farmers Market',
#  'Donut Shop',
#  'Pharmacy',
#  'Plaza',
#  'American Restaurant',
#  'Mexican Restaurant',
#  'Seafood Restaurant',
#  'Museum',
#  'Nightclub',
#  'Stadium',
#  'Credit Union',
#  'Metro Station',
#  'Chinese Restaurant',
#  'Lounge',
#  'Bus Stop',
#  'Gift Shop',
#  'Steakhouse',
#  'Gym',
#  'Bar',
#  'Greek Restaurant',
#  'Brewery',
#  'Park',
#  'Fried Chicken Joint',
#  'Gas Station',
#  'Fast Food Restaurant',
#  'Intersection',
#  'Recreation Center',
#  'Historic Site',
#  'Pool',
#  'Cuban Restaurant',
#  'Market',
#  'General Entertainment',
#  'Neighborhood',
#  'Asian Restaurant',
#  'Grocery Store',
#  'Burger Joint',
#  'Bagel Shop',
#  'Restaurant',
#  'Cosmetics Shop',
#  'Art Gallery',
#  'College Theater',
#  'Noodle House',
#  'Hot Dog Joint',
#  'Electronics Store',
#  'Thrift / Vintage Store',
#  'Sports Bar',
#  'Food & Drink Shop',
#  'Discount Store',
#  'Concert Hall',
#  'Dance Studio',
#  'Salvadoran Restaurant',
#  'Soccer Stadium',
#  'Bus Station',
#  'Southern / Soul Food Restaurant',
#  'Department Store',
#  'Sports Club',
#  'Arts & Entertainment',
#  'Ice Cream Shop',
#  'Sushi Restaurant',
#  'Wine Shop',
#  'Mediterranean Restaurant',
#  'Juice Bar',
#  'Jewelry Store',
#  'Mobile Phone Shop',
#  'Paper / Office Supplies Store',
#  'Massage Studio',
#  'Shipping Store',
#  'Mattress Store',
#  'Camera Store',
#  'Bridal Shop',
#  'Shopping Mall',
#  'Optical Shop',
#  'Tailor Shop',
#  'Music Venue',
#  'Building',
#  'Rock Club',
#  'History Museum',
#  'Spa',
#  'Opera House',
#  'Pub',
#  'Salon / Barbershop',
#  'Beer Bar',
#  'Science Museum',
#  'Cocktail Bar',
#  'Basketball Stadium',
#  'Japanese Restaurant',
#  'Theme Restaurant',
#  'Wine Bar',
#  'Irish Pub',
#  'Accessories Store',
#  'Vegetarian / Vegan Restaurant',
#  'Movie Theater',
#  'Speakeasy',
#  'Basketball Court',
#  "Men's Store",
#  'Train Station',
#  'Clothing Store',
#  'College Cafeteria',
#  'Taco Place',
#  'Food',
#  'Playground',
#  'Cajun / Creole Restaurant',
#  'Tanning Salon',
#  'Supermarket',
#  'Dive Bar',
#  'Doner Restaurant',
#  'Check Cashing Service',
#  'Light Rail Station',
#  'Sporting Goods Shop',
#  'Beer Garden',
#  'Trail',
#  'Athletics & Sports',
#  'Furniture / Home Store',
#  'Supplement Shop',
#  'Cupcake Shop',
#  'Tex-Mex Restaurant',
#  'Creperie',
#  'Boutique',
#  'Bubble Tea Shop',
#  'Health Food Store',
#  'Hostel',
#  'Jazz Club',
#  'Scenic Lookout']
